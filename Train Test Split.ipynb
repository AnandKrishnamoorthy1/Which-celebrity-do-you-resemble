# %%
from PIL import Image
import glob
import os

# Set path
path = r'C:\Users\anand\Downloads\NU Classes\Deep Learning\Slides and Code\Final Project\data_full_set'

# %%
train_folders=glob.glob(path+'/train/*')
train_folders[:2]
# Out:
# []

# %%
lst=[]
for folder in train_folders[:2]:
    print(glob.glob(folder+'\*')[-2:])

# %%
import os
import random
from shutil import copyfile

#source: https://gist.github.com/bertcarremans/679624f369ed9270472e37f8333244f5

def img_train_test_split(img_source_dir, train_size):
    """
    Randomly splits images over a train and validation folder, while preserving the folder structure
    
    Parameters
    ----------
    img_source_dir : string
        Path to the folder with the images to be split. Can be absolute or relative path   
        
    train_size : float
        Proportion of the original images that need to be copied in the subdirectory in the train folder
    """    
    if not (isinstance(img_source_dir, str)):
        raise AttributeError('img_source_dir must be a string')
        
    if not os.path.exists(img_source_dir):
        raise OSError('img_source_dir does not exist')
        
    if not (isinstance(train_size, float)):
        raise AttributeError('train_size must be a float')
        
    # Set up empty folder structure if not exists
    if not os.path.exists('data'):
        os.makedirs('data')
    else:
        if not os.path.exists('data/train'):
            os.makedirs('data/train')
        if not os.path.exists('data/validation'):
            os.makedirs('data/validation')
            
    # Get the subdirectories in the main image folder
    subdirs = [subdir for subdir in os.listdir(img_source_dir) if os.path.isdir(os.path.join(img_source_dir, subdir))]

    for subdir in subdirs:
        subdir_fullpath = os.path.join(img_source_dir, subdir)
        if len(os.listdir(subdir_fullpath)) == 0:
            print(subdir_fullpath + ' is empty')
            break

        train_subdir = os.path.join('data/train', subdir)
        validation_subdir = os.path.join('data/validation', subdir)

        # Create subdirectories in train and validation folders
        if not os.path.exists(train_subdir):
            os.makedirs(train_subdir)

        if not os.path.exists(validation_subdir):
            os.makedirs(validation_subdir)

        train_counter = 0
        validation_counter = 0

        # Randomly assign an image to train or validation folder
        for filename in os.listdir(subdir_fullpath):
            if filename.endswith(".jpg") or filename.endswith(".png"): 
                fileparts = filename.split('.')

                if random.uniform(0, 1) <= train_size:
                    copyfile(os.path.join(subdir_fullpath, filename), os.path.join(train_subdir, str(train_counter) + '.' + fileparts[1]))
                    train_counter += 1
                else:
                    copyfile(os.path.join(subdir_fullpath, filename), os.path.join(validation_subdir, str(validation_counter) + '.' + fileparts[1]))
                    validation_counter += 1
                    
        print('Copied ' + str(train_counter) + ' images to data/train/' + subdir)
        print('Copied ' + str(validation_counter) + ' images to data/validation/' + subdir)

# %%
path
# Out:
# 'C:\\Users\\anand\\Downloads\\NU Classes\\Deep Learning\\Slides and Code\\Final Project\\data_full_set'

# %%
img_train_test_split(path, 0.79)
# Out:
# Copied 104 images to data/train/Aamir_Khan
# Copied 29 images to data/validation/Aamir_Khan
# Copied 58 images to data/train/Abhay_Deol
# Copied 17 images to data/validation/Abhay_Deol
# Copied 74 images to data/train/Abhishek_Bachchan
# Copied 29 images to data/validation/Abhishek_Bachchan
# Copied 84 images to data/train/Aftab_Shivdasani
# Copied 27 images to data/validation/Aftab_Shivdasani
# Copied 117 images to data/train/Aishwarya_Rai
# Copied 39 images to data/validation/Aishwarya_Rai
# Copied 88 images to data/train/Ajay_Devgn
# Copied 22 images to data/validation/Ajay_Devgn
# Copied 72 images to data/train/Akshaye_Khanna
# Copied 11 images to data/validation/Akshaye_Khanna
# Copied 94 images to data/train/Akshay_Kumar
# Copied 28 images to data/validation/Akshay_Kumar
# Copied 131 images to data/train/Alia_Bhatt
# Copied 33 images to data/validation/Alia_Bhatt
# Copied 91 images to data/train/Ameesha_Patel
# Copied 24 images to data/validation/Ameesha_Patel
# Copied 107 images to data/train/Amitabh_Bachchan
# Copied 27 images to data/validation/Amitabh_Bachchan
# Copied 100 images to data/train/Amrita_Rao
# Copied 21 images to data/validation/Amrita_Rao
# Copied 94 images to data/train/Amy_Jackson
# Copied 28 images to data/validation/Amy_Jackson
# Copied 78 images to data/train/Anil_Kapoor
# Copied 20 images to data/validation/Anil_Kapoor
# Copied 115 images to data/train/Anushka_Sharma
# Copied 44 images to data/validation/Anushka_Sharma
# Copied 117 images to data/train/Anushka_Shetty
# Copied 27 images to data/validation/Anushka_Shetty
# Copied 92 images to data/train/Arjun_Kapoor
# Copied 19 images to data/validation/Arjun_Kapoor
# Copied 70 images to data/train/Arjun_Rampal
# Copied 27 images to data/validation/Arjun_Rampal
# Copied 89 images to data/train/Arshad_Warsi
# Copied 16 images to data/validation/Arshad_Warsi
# Copied 123 images to data/train/Asin
# Copied 24 images to data/validation/Asin
# Copied 89 images to data/train/Ayushmann_Khurrana
# Copied 24 images to data/validation/Ayushmann_Khurrana
# Copied 72 images to data/train/Bhumi_Pednekar
# Copied 24 images to data/validation/Bhumi_Pednekar
# Copied 97 images to data/train/Bipasha_Basu
# Copied 24 images to data/validation/Bipasha_Basu
# Copied 64 images to data/train/Bobby_Deol
# Copied 11 images to data/validation/Bobby_Deol
# Copied 158 images to data/train/Deepika_Padukone
# Copied 36 images to data/validation/Deepika_Padukone
# Copied 115 images to data/train/Disha_Patani
# Copied 31 images to data/validation/Disha_Patani
# Copied 80 images to data/train/Emraan_Hashmi
# Copied 16 images to data/validation/Emraan_Hashmi
# Copied 90 images to data/train/Esha_Gupta
# Copied 20 images to data/validation/Esha_Gupta
# Copied 60 images to data/train/Farhan_Akhtar
# Copied 19 images to data/validation/Farhan_Akhtar
# Copied 60 images to data/train/Govinda
# Copied 17 images to data/validation/Govinda
# Copied 87 images to data/train/Hrithik_Roshan
# Copied 29 images to data/validation/Hrithik_Roshan
# Copied 97 images to data/train/Huma_Qureshi
# Copied 31 images to data/validation/Huma_Qureshi
# Copied 109 images to data/train/Ileana_D╬ô├ç├ûCruz
# Copied 35 images to data/validation/Ileana_D╬ô├ç├ûCruz
# Copied 96 images to data/train/Irrfan_Khan
# Copied 21 images to data/validation/Irrfan_Khan
# Copied 132 images to data/train/Jacqueline_Fernandez
# Copied 27 images to data/validation/Jacqueline_Fernandez
# Copied 88 images to data/train/John_Abraham
# Copied 32 images to data/validation/John_Abraham
# Copied 95 images to data/train/Juhi_Chawla
# Copied 20 images to data/validation/Juhi_Chawla
# Copied 131 images to data/train/Kajal_Aggarwal
# Copied 32 images to data/validation/Kajal_Aggarwal
# Copied 109 images to data/train/Kajol
# Copied 28 images to data/validation/Kajol
# Copied 104 images to data/train/Kangana_Ranaut
# Copied 26 images to data/validation/Kangana_Ranaut
# Copied 106 images to data/train/Kareena_Kapoor
# Copied 32 images to data/validation/Kareena_Kapoor
# Copied 105 images to data/train/Karisma_Kapoor
# Copied 19 images to data/validation/Karisma_Kapoor
# Copied 94 images to data/train/Kartik_Aaryan
# Copied 29 images to data/validation/Kartik_Aaryan
# Copied 124 images to data/train/Katrina_Kaif
# Copied 34 images to data/validation/Katrina_Kaif
# Copied 101 images to data/train/Kiara_Advani
# Copied 31 images to data/validation/Kiara_Advani
# Copied 107 images to data/train/Kriti_Kharbanda
# Copied 27 images to data/validation/Kriti_Kharbanda
# Copied 121 images to data/train/Kriti_Sanon
# Copied 31 images to data/validation/Kriti_Sanon
# Copied 52 images to data/train/Kunal_Khemu
# Copied 24 images to data/validation/Kunal_Khemu
# Copied 69 images to data/train/Lara_Dutta
# Copied 17 images to data/validation/Lara_Dutta
# Copied 114 images to data/train/Madhuri_Dixit
# Copied 29 images to data/validation/Madhuri_Dixit
# Copied 76 images to data/train/Manoj_Bajpayee
# Copied 17 images to data/validation/Manoj_Bajpayee
# Copied 79 images to data/train/Mrunal_Thakur
# Copied 28 images to data/validation/Mrunal_Thakur
# Copied 67 images to data/train/Nana_Patekar
# Copied 14 images to data/validation/Nana_Patekar
# Copied 90 images to data/train/Nargis_Fakhri
# Copied 33 images to data/validation/Nargis_Fakhri
# Copied 65 images to data/train/Naseeruddin_Shah
# Copied 17 images to data/validation/Naseeruddin_Shah
# Copied 86 images to data/train/Nushrat_Bharucha
# Copied 24 images to data/validation/Nushrat_Bharucha
# Copied 65 images to data/train/Paresh_Rawal
# Copied 17 images to data/validation/Paresh_Rawal
# Copied 102 images to data/train/Parineeti_Chopra
# Copied 24 images to data/validation/Parineeti_Chopra
# Copied 121 images to data/train/Pooja_Hegde
# Copied 29 images to data/validation/Pooja_Hegde
# Copied 114 images to data/train/Prabhas
# Copied 24 images to data/validation/Prabhas
# Copied 92 images to data/train/Prachi_Desai
# Copied 23 images to data/validation/Prachi_Desai
# Copied 101 images to data/train/Preity_Zinta
# Copied 32 images to data/validation/Preity_Zinta
# Copied 106 images to data/train/Priyanka_Chopra
# Copied 30 images to data/validation/Priyanka_Chopra
# Copied 77 images to data/train/Rajkummar_Rao
# Copied 21 images to data/validation/Rajkummar_Rao
# Copied 90 images to data/train/Ranbir_Kapoor
# Copied 29 images to data/validation/Ranbir_Kapoor
# Copied 91 images to data/train/Randeep_Hooda
# Copied 18 images to data/validation/Randeep_Hooda
# Copied 96 images to data/train/Rani_Mukerji
# Copied 32 images to data/validation/Rani_Mukerji
# Copied 102 images to data/train/Ranveer_Singh
# Copied 23 images to data/validation/Ranveer_Singh
# Copied 89 images to data/train/Richa_Chadda
# Copied 28 images to data/validation/Richa_Chadda
# Copied 66 images to data/train/Riteish_Deshmukh
# Copied 17 images to data/validation/Riteish_Deshmukh
# Copied 78 images to data/train/R_Madhavan
# Copied 17 images to data/validation/R_Madhavan
# Copied 73 images to data/train/Saif_Ali_Khan
# Copied 26 images to data/validation/Saif_Ali_Khan
# Copied 111 images to data/train/Salman_Khan
# Copied 29 images to data/validation/Salman_Khan
# Copied 83 images to data/train/Sanjay_Dutt
# Copied 18 images to data/validation/Sanjay_Dutt
# Copied 75 images to data/train/Sara_Ali_Khan
# Copied 36 images to data/validation/Sara_Ali_Khan
# Copied 111 images to data/train/Shahid_Kapoor
# Copied 30 images to data/validation/Shahid_Kapoor
# Copied 95 images to data/train/Shah_Rukh_Khan
# Copied 23 images to data/validation/Shah_Rukh_Khan
# Copied 110 images to data/train/Shilpa_Shetty
# Copied 30 images to data/validation/Shilpa_Shetty
# Copied 92 images to data/train/Shraddha_Kapoor
# Copied 22 images to data/validation/Shraddha_Kapoor
# Copied 41 images to data/train/Shreyas_Talpade
# Copied 14 images to data/validation/Shreyas_Talpade
# Copied 105 images to data/train/Shruti_Haasan
# Copied 24 images to data/validation/Shruti_Haasan
# Copied 84 images to data/train/Sidharth_Malhotra
# Copied 15 images to data/validation/Sidharth_Malhotra
# Copied 97 images to data/train/Sonakshi_Sinha
# Copied 27 images to data/validation/Sonakshi_Sinha
# Copied 103 images to data/train/Sonam_Kapoor
# Copied 28 images to data/validation/Sonam_Kapoor
# Copied 55 images to data/train/Suniel_Shetty
# Copied 16 images to data/validation/Suniel_Shetty
# Copied 65 images to data/train/Sunny_Deol
# Copied 16 images to data/validation/Sunny_Deol
# Copied 85 images to data/train/Sushant_Singh_Rajput
# Copied 15 images to data/validation/Sushant_Singh_Rajput
# Copied 115 images to data/train/Taapsee_Pannu
# Copied 24 images to data/validation/Taapsee_Pannu
# Copied 87 images to data/train/Tabu
# Copied 29 images to data/validation/Tabu
# Copied 135 images to data/train/Tamannaah_Bhatia
# Copied 43 images to data/validation/Tamannaah_Bhatia
# Copied 104 images to data/train/Tiger_Shroff
# Copied 23 images to data/validation/Tiger_Shroff
# Copied 48 images to data/train/Tusshar_Kapoor
# Copied 14 images to data/validation/Tusshar_Kapoor
# Copied 62 images to data/train/Uday_Chopra
# Copied 12 images to data/validation/Uday_Chopra
# Copied 120 images to data/train/Vaani_Kapoor
# Copied 32 images to data/validation/Vaani_Kapoor
# Copied 114 images to data/train/Varun_Dhawan
# Copied 23 images to data/validation/Varun_Dhawan
# Copied 75 images to data/train/Vicky_Kaushal
# Copied 25 images to data/validation/Vicky_Kaushal
# Copied 121 images to data/train/Vidya_Balan
# Copied 23 images to data/validation/Vidya_Balan
# Copied 63 images to data/train/Vivek_Oberoi
# Copied 17 images to data/validation/Vivek_Oberoi
# Copied 119 images to data/train/Yami_Gautam
# Copied 42 images to data/validation/Yami_Gautam
# Copied 107 images to data/train/Zareen_Khan
# Copied 34 images to data/validation/Zareen_Khan

# %%
print("Done!")
# Out:
# Done!
